# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/My Drive')

# %%
# !ls
# Out:
#  cached		        lumon-transcript-full.csv	 output-small
# 'Colab Notebooks'       lumon-transcript-full.txt	 runs
#  kaggle.json	        megaGymDataset.csv
#  lumon-transcript.csv   megaGymDataset-transcript2.csv

# %%
import re
import pandas as pd

# %%
pattern = r'([a-zA-Z\s]+):(.+)'

# %%
data = {
    'name': [],
    'line': []
}

# %%
with open('lumon-transcript-full.txt', 'rt') as file:
  for line in file.readlines():
    match = re.findall(pattern, line)
    if match:
      name, line = match[0]
      data['name'].append(name)
      data['line'].append(line)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     name                                               line
# 0   Mark                                       Who are you?
# 1   Mark                                       Who are you?
# 2  Helly                                             Hello?
# 3   Mark                  I’m sorry, I got ahead of myself.
# 4   Mark   Hi there, you on the table. I wonder if you’d...

# %%
sum(df['name'] == 'Mark')
# Out:
# 1403

# %%
df.query('name.str.startswith("Mark")')
# Out:
#       name                                               line
# 0     Mark                                       Who are you?
# 1     Mark                                       Who are you?
# 3     Mark                  I’m sorry, I got ahead of myself.
# 4     Mark   Hi there, you on the table. I wonder if you’d...
# 6     Mark                                    Five questions.
# ...    ...                                                ...
# 6004  Mark                                        Are you my–
# 6006  Mark                                       She's alive.
# 6040  Mark                                       Right. Okay.
# 6081  Mark                                              Okay.
# 6132  Mark                                              Okay.
#
# [1524 rows x 2 columns]

# %%
len(df)
# Out:
# 6251

# %%
df.to_csv('lumon-transcript-full.csv', index=False)
